# %%
# -*- coding: utf-8 -*-
"""DS_Day1.ipynb
# Out:
#   Cell In[2], line 2
#     """DS_Day1.ipynb
#     ^
# SyntaxError: incomplete input

# %%
Automatically generated by Colaboratory.

# %%
Original file is located at
    https://colab.research.google.com/drive/1e_nWbF8oWHMcVs0X-zw3IHm3SR2DNPMY
"""

# %%
# 1. **Python Output**
# <br>
print(True)
print("Hello World")
print("Salman Khan")
# print(Salman khan)
print("Bhaio", 123,True, sep = "/")
print("Hello", "World", sep = '-')
print("Hello", end = " ")
print("world")
print("Hello khan")
print(123,True,"Baba", sep = "/", end  =" ")
print("karachi")
#2. Data Types

# %% [markdown]
# nteger

# %%
print(8)

# %% [markdown]
# e309

# %%
print(1e309)
print(1e123)

# %% [markdown]
# ecimal/float

# %%
print(1.76)
print

# %%
print(True)
print(False)

# %% [markdown]
# ext/String

# %%
print("Assalam o Alaikum")

# %% [markdown]
# complex

# %%
print(5+6j)
print(5+6j)

# %% [markdown]
# List -> C -> Array

# %%
print([1,2,3,4,5])

# %% [markdown]
# Tuple

# %%
print((1,2,3), end = " ")
print((4,5,6))

# %% [markdown]
# Set

# %%
print({1,2,3}, end = " ", sep = "/")
print({4,5,6})

# %% [markdown]
# Dictionaries

# %%
print({'Name':'Gulzar', 'Roll No':12})
print({"Name": "Adil", "Roll No": 13})
print({"Name": "Adil", "Roll No": 456})
print({"city": "Karachi",
        "code": 206})

# %% [markdown]
# ype

# %%
type([1,2,3])

# %% [markdown]
# ariable

# %%
name = "Gulzar"
print(name)

# %%
a  = 5
b = 6
print(a + b)
print(a + b)

# %% [markdown]
# Dynamic -> automatically understand what kind of value python variable have

# %%
a = 5
print(type(a))

# %% [markdown]
# static <br>
# int a = 5

# %% [markdown]
# Dynamic binding -> Variables value change as per requirements

# %%
a  = 10
print(a)

# %%
a = 'Gulzar'
print(a)

# %% [markdown]
# tatic binding -> The value does not change if any condition<br>
# int a = 10

# %% [markdown]
# python intelligent

# %%
a = 1
b = 2
c = 12
print(a,b,c)

# %%
a,b,c = 2,4,6
x,y,z = 5,7,8
print(a,b,c)
print(x,y,z)

# %%
a=b=c = 5
a=b=c = 1
print(b)

# %% [markdown]
# ### Comments<br>

# %% [markdown]
# comment

# %% [markdown]
# Kayword -> basically predefined word in every language <br>
# like : as, if, is, in

# %% [markdown]
# Identifiers -> basically we will create it or edit it, and can not starting with digits or special character

# %%
first_name = "Gulzar"
Second_name = "Alam"
print(first_name, Second_name, end = " ")
print(first_name, Second_name)
print(first_name + Second_name, sep = "-")

# %% [markdown]
# identifiers can not be keyword

# %% [markdown]
# static (remain same) vs Dynamic (real time changes)

# %%
input("Enter your good name ")

# %% [markdown]
# Example of dynamic

# %%
first_number = input("Enter first number  ")
second_number=input("Enter second number  ")
print(type(first_number), type(second_number))
print(type(first_number), type(second_number))
# Out:
# Enter first number  1
# Enter second number  1
# <class 'str'> <class 'str'>
# <class 'str'> <class 'str'>

# %% [markdown]
# add two number

# %%
sum = first_number + second_number
print(sum)
# Out:
# 11

# %% [markdown]
# Type conversion

# %% [markdown]
# implicit (interpreter solve itself and find which type of data type ) vs explicit (programmer request to python to change the data type)

# %% [markdown]
# example of implicit

# %%
print(5 + 5.5)
print(type(5), type(5.5))
# Out:
# 10.5
# <class 'int'> <class 'float'>

# %%
print(5 + "5")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(5 + "5")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# xplicit has builtin function like: str, int

# %% [markdown]
# str -> int

# %%
print("4")

# %% [markdown]
# equested to program to change data type

# %%
type(int('4'))
type(str(3))

# %% [markdown]
# int -> str

# %%
str(5)

# %% [markdown]
# Example<br>
# 1. take input from users and stored them in variable

# %%
fnum = input("Enter first number: ")
snum = input("Enter second number: ")

# %% [markdown]
# add the two number

# %%
sum = int(fnum) + int(snum)
print(sum)
print(type(fnum))

# %% [markdown]
# Literals

# %%
a = 0b1010 #Binary literal
print(a)

# %%
b = 100
print(b) #Decimal literals

# %%
c = 0o310 #octal literals
print(c)

# %%
d = 0x12c #Hexa Decimal
print(c)

# %% [markdown]
# Operators<br>
# 1.Arithmetic<br>
# 2. Logical <br>
# 3. Assignment<br>
# 4. Bitwise<br>
# 5. Relational<br>
# 6. Membership

# %% [markdown]
# loat literals

# %%
float_1 = 1.5
float_2 = 1.5e2 #1.5 x 10^2
float_3 = 1.5e-2

# %%
print(float_1, float_2, float_3)
# Out:
# 1.5 150.0 0.015

# %% [markdown]
# omplex literals

# %%
a = 3.14j
b = 3.14j
print(b.real, b.imag)
print(a.real, a.imag)
# Out:
# 0.0 3.14
# 0.0 3.14

# %% [markdown]
# Python String

# %%
string = 'This is python'
strings = "This is python"
char = 'C'
unicode = u"\U0001f600"
raw_data=r"raw \n string"

# %%
print(string)
print(strings)
print(char)
print(unicode)
print(raw_data)
# Out:
# This is python
# This is python
# C
# 😀
# raw \n string

# %%
a = True + 1
b = False - 1

# %%
print("a:" , a)
print("b:" ,  b)
# Out:
# a: 2
# b: -1

# %%
a = None
print(a )
# Out:
# None
